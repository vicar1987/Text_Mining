# %%
pip install feedparser
# Out:
# Collecting feedparser
#   Using cached feedparser-6.0.8-py3-none-any.whl (81 kB)
# Collecting sgmllib3k
#   Using cached sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=2104b67e2d00c2637f65fc02502f9c38786cea6423ce157873ddac62b04bfaa5
#   Stored in directory: /Users/vicar1987/Library/Caches/pip/wheels/65/7a/a7/78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.8 sgmllib3k-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import feedparser

# %%
rss_url = "https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money"

# %%
newsFeed = feedparser.parse(rss_url)
newsFeed
# Out:
# ',
#     'value': '美國商務部今天增列34家國外實體進入黑名單，包括14個涉嫌在新疆侵犯人權與進行科技監控的中國實體，以及5家支持中國軍事現...'},
#    'id': 'https://money.udn.com/money/story/10511/5591479',
#    'guidislink': False},
#   {'title': '美商務部增列新制裁名單 14家大陸企業上榜',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美商務部增列新制裁名單 14家大陸企業上榜'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5591120'}],
#    'link': 'https://money.udn.com/money/story/10511/5591120',
#    'published': 'Fri, 09 Jul 2021 22:12:23 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=14, tm_min=12, tm_sec=23, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/04/25/realtime/12172173.jpg&amp;s=Y&amp;x=100&amp;y=0&amp;sw=1080&amp;sh=720&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國商務部的工業和安全局9日增列34家企業進入經濟制裁的黑名單，其中14家位在中國大陸，原因是協助北京在新疆迫害人權，對...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/04/25/realtime/12172173.jpg&amp;s=Y&amp;x=100&amp;y=0&amp;sw=1080&amp;sh=720&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國商務部的工業和安全局9日增列34家企業進入經濟制裁的黑名單，其中14家位在中國大陸，原因是協助北京在新疆迫害人權，對...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5591120',
#    'guidislink': False},
#   {'title': '季辛吉秘密訪問大陸50年 北京舉行紀念活動',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '季辛吉秘密訪問大陸50年 北京舉行紀念活動'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5590983'}],
#    'link': 'https://money.udn.com/money/story/10511/5590983',
#    'published': 'Fri, 09 Jul 2021 20:38:24 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=12, tm_min=38, tm_sec=24, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12940977.png&amp;s=Y&amp;x=197&amp;y=0&amp;sw=885&amp;sh=591&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>大陸國家副主席王岐山今日出席前美國國務卿季辛吉秘密訪問中國大陸50年活動。王岐山致詞時指出，當前中美關係正處在關鍵時刻，...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12940977.png&amp;s=Y&amp;x=197&amp;y=0&amp;sw=885&amp;sh=591&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>大陸國家副主席王岐山今日出席前美國國務卿季辛吉秘密訪問中國大陸50年活動。王岐山致詞時指出，當前中美關係正處在關鍵時刻，...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5590983',
#    'guidislink': False},
#   {'title': '美中關係緊張 季辛吉呼籲：對話應快展開',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美中關係緊張 季辛吉呼籲：對話應快展開'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5590837'}],
#    'link': 'https://money.udn.com/money/story/10511/5590837',
#    'published': 'Fri, 09 Jul 2021 18:49:23 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=10, tm_min=49, tm_sec=23, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12939754.jpg&amp;s=Y&amp;x=71&amp;y=0&amp;sw=657&amp;sh=438&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>今日是前美國國務卿季辛吉秘密訪問中國大陸50年，季辛吉在一場紀念活動上表示，美中關係再次緊張的時刻，對話應該儘快展開。</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12939754.jpg&amp;s=Y&amp;x=71&amp;y=0&amp;sw=657&amp;sh=438&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>今日是前美國國務卿季辛吉秘密訪問中國大陸50年，季辛吉在一場紀念活動上表示，美中關係再次緊張的時刻，對話應該儘快展開。</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5590837',
#    'guidislink': False},
#   {'title': '季辛格秘密訪問大陸50年 北京：求同存異中美可共處',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '季辛格秘密訪問大陸50年 北京：求同存異中美可共處'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5590833'}],
#    'link': 'https://money.udn.com/money/story/10511/5590833',
#    'published': 'Fri, 09 Jul 2021 18:48:23 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=10, tm_min=48, tm_sec=23, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12939742.jpg&amp;s=Y&amp;x=87&amp;y=0&amp;sw=906&amp;sh=604&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>今日是美國前國務卿季辛吉秘密訪問中國大陸50 年，大陸外交部發言人汪文斌今表示，季辛吉訪華的歷史啟示是，中美雖制度不同，...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12939742.jpg&amp;s=Y&amp;x=87&amp;y=0&amp;sw=906&amp;sh=604&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>今日是美國前國務卿季辛吉秘密訪問中國大陸50 年，大陸外交部發言人汪文斌今表示，季辛吉訪華的歷史啟示是，中美雖制度不同，...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5590833',
#    'guidislink': False},
#   {'title': '季辛吉訪陸50年 王岐山：中美應對話協商處理分歧',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '季辛吉訪陸50年 王岐山：中美應對話協商處理分歧'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5590832'}],
#    'link': 'https://money.udn.com/money/story/10511/5590832',
#    'published': 'Fri, 09 Jul 2021 18:47:26 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=10, tm_min=47, tm_sec=26, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12939727.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=600&amp;sh=408&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>大陸國家副主席王岐山今日表示，中美三個聯合公報為雙方正確處理中美關係提供根本遵循。雙方要堅持三個聯合公報的精神，透過對話...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12939727.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=600&amp;sh=408&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>大陸國家副主席王岐山今日表示，中美三個聯合公報為雙方正確處理中美關係提供根本遵循。雙方要堅持三個聯合公報的精神，透過對話...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5590832',
#    'guidislink': False},
#   {'title': '傳美擬將14家中企列入黑名單  北京：堅決反對',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '傳美擬將14家中企列入黑名單  北京：堅決反對'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5590650'}],
#    'link': 'https://money.udn.com/money/story/10511/5590650',
#    'published': 'Fri, 09 Jul 2021 17:21:26 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=9, tm_min=21, tm_sec=26, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '美國傳將再以侵犯新疆人權為由，把14家中國企業列入經濟黑名單。中國外交部發言人汪文斌今天則說，中方堅決反對美方打壓，將採...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國傳將再以侵犯新疆人權為由，把14家中國企業列入經濟黑名單。中國外交部發言人汪文斌今天則說，中方堅決反對美方打壓，將採...'},
#    'id': 'https://money.udn.com/money/story/10511/5590650',
#    'guidislink': False},
#   {'title': '美稱拒簽大陸留學生只影響極少數人 陸呼籲停止打壓',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美稱拒簽大陸留學生只影響極少數人 陸呼籲停止打壓'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5590645'}],
#    'link': 'https://money.udn.com/money/story/10511/5590645',
#    'published': 'Fri, 09 Jul 2021 17:19:27 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=9, tm_min=19, tm_sec=27, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12938356.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=500&amp;sh=335&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>近日有500多名中國理工科研究生申請赴美簽證時被拒簽，美國國務院發言人對此回應，只影響少於2%的中國籍申請人。大陸外交部...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12938356.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=500&amp;sh=335&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>近日有500多名中國理工科研究生申請赴美簽證時被拒簽，美國國務院發言人對此回應，只影響少於2%的中國籍申請人。大陸外交部...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5590645',
#    'guidislink': False},
#   {'title': '美將把逾10家陸企納入黑名單 陸外交部：禍亂新疆手段',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美將把逾10家陸企納入黑名單 陸外交部：禍亂新疆手段'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5590640'}],
#    'link': 'https://money.udn.com/money/story/10511/5590640',
#    'published': 'Fri, 09 Jul 2021 17:16:01 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=9, tm_min=16, tm_sec=1, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12938332.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=500&amp;sh=335&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國總統拜登政府最快將於明日再把10幾家大陸企業列入經濟黑名單，原因為這些中企新疆侵犯人權並使用高科技監控。大陸外交部9...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12938332.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=500&amp;sh=335&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國總統拜登政府最快將於明日再把10幾家大陸企業列入經濟黑名單，原因為這些中企新疆侵犯人權並使用高科技監控。大陸外交部9...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5590640',
#    'guidislink': False},
#   {'title': '季辛吉：美中應循「尼克森模式」化解緊張',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '季辛吉：美中應循「尼克森模式」化解緊張'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5590407'}],
#    'link': 'https://money.udn.com/money/story/10511/5590407',
#    'published': 'Fri, 09 Jul 2021 16:00:29 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=8, tm_min=0, tm_sec=29, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '97歲的美國前國務卿季辛吉（Henry Kissinger）今天透過視訊出席在北京舉行的研討會時指出，美中需要立刻對話，...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '97歲的美國前國務卿季辛吉（Henry Kissinger）今天透過視訊出席在北京舉行的研討會時指出，美中需要立刻對話，...'},
#    'id': 'https://money.udn.com/money/story/10511/5590407',
#    'guidislink': False},
#   {'title': '美傳再列至少十個大陸實體進黑名單 認定侵犯新疆人權',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美傳再列至少十個大陸實體進黑名單 認定侵犯新疆人權'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5589609'}],
#    'link': 'https://money.udn.com/money/story/10511/5589609',
#    'published': 'Fri, 09 Jul 2021 12:02:25 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=4, tm_min=2, tm_sec=25, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12933561.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>路透引述消息人士報導，拜登政府最快今（9）日宣布，將進一步把至少十個中國大陸實體加入經濟黑名單，理由是涉嫌在新疆侵犯人權...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12933561.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>路透引述消息人士報導，拜登政府最快今（9）日宣布，將進一步把至少十個中國大陸實體加入經濟黑名單，理由是涉嫌在新疆侵犯人權...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5589609',
#    'guidislink': False},
#   {'title': '侵犯新疆人權 路透：美將把10多家中國公司列入黑名單',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '侵犯新疆人權 路透：美將把10多家中國公司列入黑名單'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5589497'}],
#    'link': 'https://money.udn.com/money/story/10511/5589497',
#    'published': 'Fri, 09 Jul 2021 11:35:26 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=3, tm_min=35, tm_sec=26, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12933087.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國政府最快在當地時間9日，把至少10間中國公司和其他實體列入黑名單。</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12933087.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國政府最快在當地時間9日，把至少10間中國公司和其他實體列入黑名單。</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5589497',
#    'guidislink': False},
#   {'title': '滴滴上市案是否誤導美國投資人？參議員籲SEC啟動調查',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '滴滴上市案是否誤導美國投資人？參議員籲SEC啟動調查'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5589215'}],
#    'link': 'https://money.udn.com/money/story/10511/5589215',
#    'published': 'Fri, 09 Jul 2021 10:18:18 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=9, tm_hour=2, tm_min=18, tm_sec=18, tm_wday=4, tm_yday=190, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12932009.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國兩位重量級參議員呼籲證管會（SEC）對滴滴出行展開調查，認為這個中國大陸叫車平台誤導美國投資人，因上市前並未充分揭露...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/09/realtime/12932009.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國兩位重量級參議員呼籲證管會（SEC）對滴滴出行展開調查，認為這個中國大陸叫車平台誤導美國投資人，因上市前並未充分揭露...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/5589215',
#    'guidislink': False},
#   {'title': '推文現台灣國旗 白宮：團隊無心之過美國政策未變',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '推文現台灣國旗 白宮：團隊無心之過美國政策未變'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5588927'}],
#    'link': 'https://money.udn.com/money/story/10511/5588927',
#    'published': 'Fri, 09 Jul 2021 03:01:35 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=8, tm_hour=19, tm_min=1, tm_sec=35, tm_wday=3, tm_yday=189, tm_isdst=0),
#    'summary': '美國白宮COVID-19應變小組日前推文提及台灣，更秀出中華民國國旗，卻在事後刪文，引發熱議。白宮發言人莎琪今天解釋，那...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國白宮COVID-19應變小組日前推文提及台灣，更秀出中華民國國旗，卻在事後刪文，引發熱議。白宮發言人莎琪今天解釋，那...'},
#    'id': 'https://money.udn.com/money/story/10511/5588927',
#    'guidislink': False},
#   {'title': '川規拜隨 美延長就香港局勢所頒緊急狀態',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '川規拜隨 美延長就香港局勢所頒緊急狀態'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/5587130'}],
#    'link': 'https://money.udn.com/money/story/10511/5587130',
#    'published': 'Thu, 08 Jul 2021 13:45:23 +0800',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=8, tm_hour=5, tm_min=45, tm_sec=23, tm_wday=3, tm_yday=189, tm_isdst=0),
#    'summary': '美國白宮今天發布公告指出，有鑒北京對香港採取的行動繼續對美國構成威脅，總統拜登決定把川普政府時期就香港局勢宣布的國家緊急...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國白宮今天發布公告指出，有鑒北京對香港採取的行動繼續對美國構成威脅，總統拜登決定把川普政府時期就香港局勢宣布的國家緊急...'},
#    'id': 'https://money.udn.com/money/story/10511/5587130',
#    'guidislink': False}],
#  'feed': {'title': '經濟日報',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#    'value': '經濟日報'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://money.udn.com'}],
#   'link': 'https://money.udn.com',
#   'subtitle': '經濟日報(https://money.udn.com)每日透過專業記者群，將即時、熱點、國際、行情、證券、兩岸、產業、酷科技、生技、理財、房產、品味、觀點及商情等等最新資訊彙整成當天重要新聞，提供最新最精闢的內容，為工商業界每日必讀的新聞網站。',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#    'value': '經濟日報(https://money.udn.com)每日透過專業記者群，將即時、熱點、國際、行情、證券、兩岸、產業、酷科技、生技、理財、房產、品味、觀點及商情等等最新資訊彙整成當天重要新聞，提供最新最精闢的內容，為工商業界每日必讀的新聞網站。'},
#   'published': 'Mon, 12 Jul 2021 23:35:03 +0800',
#   'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=12, tm_hour=15, tm_min=35, tm_sec=3, tm_wday=0, tm_yday=193, tm_isdst=0),
#   'rights': '聯合線上公司著作權所有@copy; udn.com. All Rights Reserved.',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#    'value': '聯合線上公司著作權所有@copy; udn.com. All Rights Reserved.'},
#   'language': 'zh-TW',
#   'ttl': '10'},
#  'headers': {'server': 'u-t-a',
#   'content-encoding': 'gzip',
#   'strict-transport-security': 'max-age=15768000',
#   'x-e': 'Money146',
#   'access-control-allow-origin': '*',
#   'access-control-allow-headers': 'Origin, No-Cache, X-Requested-With, If-Modified-Since, Pragma, Last-Modified, Cache-Control, Expires, Content-Type, X-E4M-With',
#   'content-length': '3873',
#   'content-type': 'text/xml',
#   'date': 'Mon, 12 Jul 2021 15:42:59 GMT',
#   'connection': 'close',
#   'vary': 'Accept-Encoding'},
#  'href': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#  'status': 200,
#  'encoding': 'utf-8',
#  'bozo_exception': feedparser.exceptions.CharacterEncodingOverride('document declared as us-ascii, but parsed as utf-8'),
#  'version': 'rss20',
#  'namespaces': {}}

# %%
i = 1
for e in newsFeed['entries']:
    title = e['title']
    link_url = e['links'][0]['href']
    print("%s, %s, %s"%(i, title, link_url))
    i = i + 1
# Out:
# 1, 美國想切斷中國企業金脈 北京助陣加速雙邊脫鉤, https://money.udn.com/money/story/10511/5596770
# 2, 美媒稱全球抗疫美國第一   趙立堅：只能表示「呵呵」, https://money.udn.com/money/story/10511/5596282
# 3, 德州艾爾帕索傳槍響  已知1死5傷, https://money.udn.com/money/story/10511/5594868
# 4, 中國副外長：美國霸權衰落  秀肌肉嚇不倒中國人, https://money.udn.com/money/story/10511/5592075
# 5, 陸副外長譏諷美國衰落是霸權的衰落 更是思想的衰落, https://money.udn.com/money/story/10511/5591672
# 6, 美添34實體清單  含14家侵犯新疆人權中國企業, https://money.udn.com/money/story/10511/5591479
# 7, 美商務部增列新制裁名單 14家大陸企業上榜, https://money.udn.com/money/story/10511/5591120
# 8, 季辛吉秘密訪問大陸50年 北京舉行紀念活動, https://money.udn.com/money/story/10511/5590983
# 9, 美中關係緊張 季辛吉呼籲：對話應快展開, https://money.udn.com/money/story/10511/5590837
# 10, 季辛格秘密訪問大陸50年 北京：求同存異中美可共處, https://money.udn.com/money/story/10511/5590833
# 11, 季辛吉訪陸50年 王岐山：中美應對話協商處理分歧, https://money.udn.com/money/story/10511/5590832
# 12, 傳美擬將14家中企列入黑名單  北京：堅決反對, https://money.udn.com/money/story/10511/5590650
# 13, 美稱拒簽大陸留學生只影響極少數人 陸呼籲停止打壓, https://money.udn.com/money/story/10511/5590645
# 14, 美將把逾10家陸企納入黑名單 陸外交部：禍亂新疆手段, https://money.udn.com/money/story/10511/5590640
# 15, 季辛吉：美中應循「尼克森模式」化解緊張, https://money.udn.com/money/story/10511/5590407
# 16, 美傳再列至少十個大陸實體進黑名單 認定侵犯新疆人權, https://money.udn.com/money/story/10511/5589609
# 17, 侵犯新疆人權 路透：美將把10多家中國公司列入黑名單, https://money.udn.com/money/story/10511/5589497
# 18, 滴滴上市案是否誤導美國投資人？參議員籲SEC啟動調查, https://money.udn.com/money/story/10511/5589215
# 19, 推文現台灣國旗 白宮：團隊無心之過美國政策未變, https://money.udn.com/money/story/10511/5588927
# 20, 川規拜隨 美延長就香港局勢所頒緊急狀態, https://money.udn.com/money/story/10511/5587130

# %%
pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting chardet<5,>=3.0.2
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vicar1987/.conda/envs/pythonProject/lib/python3.9/site-packages (from requests) (2021.5.30)
# Installing collected packages: urllib3, idna, chardet, requests
# Successfully installed chardet-4.0.0 idna-2.10 requests-2.25.1 urllib3-1.26.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.6.3-cp39-cp39-macosx_10_9_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 2.4 MB/s
# Installing collected packages: lxml
# Successfully installed lxml-4.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jieba
# Out:
# Collecting jieba
#   Using cached jieba-0.42.1-py3-none-any.whl
# Installing collected packages: jieba
# Successfully installed jieba-0.42.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl (11.6 MB)
# Collecting numpy>=1.17.3
#   Downloading numpy-1.21.0-cp39-cp39-macosx_10_9_x86_64.whl (16.9 MB)
#      |████████████████████████████████| 16.9 MB 6.0 MB/s
# Collecting pytz>=2017.3
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/vicar1987/.conda/envs/pythonProject/lib/python3.9/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /Users/vicar1987/.conda/envs/pythonProject/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.21.0 pandas-1.3.0 pytz-2021.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from lxml import etree
from io import StringIO
import jieba
import pandas as pd
import time
import random

# %%
jieba.set_dictionary('Word_Dictionary/dict.txt.big')

# %%
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36"
my_headers = {
    'User-Agent': user_agent,
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    "accept-encoding": "gzip, deflate, br",
    "Connection": "keep-alive",
    "cache-control": "no-cache",
    "Accept-Charset": "UTF8,utf-8;q=0.7,*;q=0.7"
}

# %%
each_article_text_list = []
for e in newsFeed['entries']:
    url = e['links'][0]['href']
    print(url)
    r = requests.get(url, headers = my_headers)
    if r.status_code == 200:
        parse_tree = etree.parse(StringIO(r.text), etree.HTMLParser())
        article_elements = parse_tree.xpath('//*[@id="article_body"]//p')
        for a_part in article_elements:
            if type(a_part.text) is str:
                each_article_text_list.append(a_part.text.strip())
        sleep_time = random.randint(3,10)
        print("sleep time: %s sec"%(sleep_time))
        time.sleep(sleep_time)
    all_article_text = ''.join(each_article_text_list)
all_article_text
# Out:
# https://money.udn.com/money/story/10511/5596770
# sleep time: 6 sec
# https://money.udn.com/money/story/10511/5596282
# sleep time: 5 sec
# https://money.udn.com/money/story/10511/5594868
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/5592075
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/5591672
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/5591479
# sleep time: 9 sec
# https://money.udn.com/money/story/10511/5591120
# sleep time: 6 sec
# https://money.udn.com/money/story/10511/5590983
# sleep time: 9 sec
# https://money.udn.com/money/story/10511/5590837
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/5590833
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/5590832
# sleep time: 9 sec
# https://money.udn.com/money/story/10511/5590650
# sleep time: 8 sec
# https://money.udn.com/money/story/10511/5590645
# sleep time: 4 sec
# https://money.udn.com/money/story/10511/5590640
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/5590407
# sleep time: 4 sec
# https://money.udn.com/money/story/10511/5589609
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/5589497
# sleep time: 7 sec
# https://money.udn.com/money/story/10511/5589215
# sleep time: 9 sec
# https://money.udn.com/money/story/10511/5588927
# sleep time: 5 sec
# https://money.udn.com/money/story/10511/5587130
# sleep time: 6 sec
# "3年來2位美國總統接連努力打壓中國企業到全球最大資本市場美國籌資，如今卻從意想不到的來源獲得助力：中國政府。日經亞洲（Nikkei Asia）報導，北京高層警告對個資安全和企業海外上市將採更嚴格監管，加上中國經濟成長放緩及政府加強管理，已使得在美國股票市場掛牌的中國企業風險大增，因此引發投資人拋售潮，同時也影響到其他中企在美國上市計畫。根據追蹤98家在美國掛牌中企股票的那斯達克金龍中國指數（Nasdaq Golden Dragon China Index），這類中企股價目前和美股大盤差距達到至少是2016年9月以來最高，比美國前總統川普（Donald Trump）任內美中貿易戰最激烈時的低價程度更慘烈。那斯達克金龍中國指數從本月2日至今大跌了10.5%，當天中國國家互聯網信息辦公室以「防範國家數據安全風險，維護國家安全」為由，對2天前才在美國首次公開募股（IPO）、籌得44億美元（約新台幣1232億元）的中國最大叫車服務軟體公司滴滴出行實施網路安全審查，期間停止新用戶註冊。那斯達克金龍中國指數和大盤指數的差距，也以至少5年來最快速度擴大，反映出投資人情緒迅速轉變及市場受驚嚇的程度。中國網信辦10日更進一步公告「網絡安全審查辦法」修訂草案，規定掌握超過100萬用戶個資的企業若欲赴海外上市，須申請網路安全審查。這幾乎影響到所有有意在海外IPO的中企。分析師發現，北京的動機是要減少中國對美國和美方監管當局的曝險；一方面是為保護資訊，另方面降低中國企業對全球最大資本市場美國的籌資依賴。川普2018年開打貿易戰，迫使中國去年宣布在科技和半導體等重要產業推動自給自足的計畫。川普在任期尾聲還對連串中國企業祭出投資禁令，並贊成實施規定令中企下市。美國去年已通過立法，要求在美國掛牌的中國企業必須讓美國監管機關審查會計審計紀錄，否則可能將在2023年底前被迫下市。現任美國總統拜登（Joe Biden）至今也大致維持川普政府對北京的施壓，他6月簽署行政命令，禁止美國居民和實體投資據控與解放軍有關係的59家中國企業。包括中國移動等數家中國電信企業已在美國交易所下市。但根據美國國會授權成立的「美中經濟暨安全檢討委員會」（US-China Economic and Security ReviewCommission）統計，截至今年5月5日，共有248家中企在美國股票交易所上市，合計市值達到2兆1000億美元（近新台幣59兆元）。「紅色資本主義：中國驚人崛起的脆弱金融基礎」（Red Capitalism: The Fragile FinancialFoundation of China's Extraordinary Rise，暫譯）一書共同作者、市場分析師郝伊（Fraser Howie）表示：「長期以來，中國渴望在眾多產業達到自給自足，其中若包含資本市場也很合理。」郝伊說：「中國會比較希望國內企業在境內掛牌，或至少在香港上市，因為北京想要由他們來監管自家企業。至於已赴海外上市中企，他們的成長展望已不再亮眼，投資人已開始對這類股票重新估價。」大陸外交部發言人趙立堅今天主持例行記者會，有記者提問，彭博社日前發布新一期的全球抗疫排名，美國排名第一，成為全球第一抗疫大國，中國排名第八，中方有何評論？趙立堅回應說：「這幾天我的好幾位同事和朋友都在問我，彭博社這個報告是不是印錯了？他們還問，在他們心中一向權威的彭博社，怎麼能如此小兒科？」他並指出，看到有關報導說，彭博社的所謂全球抗疫排名，為了達到美國第一的結果，不惜將以往排名中最為關鍵的確診病例和死亡人數等要素刪掉，並將執行封鎖和出入境防疫管理政策視為負面因素，這既不符合事實，也不尊重科學，更不尊重生命。趙立堅說，中國人常說，老百姓心中有桿秤，群眾的眼睛是雪亮的。所謂的排名和民調結果，把黑的說成白的，白的說成黑的，也許今後還能把死的說成活的。「我想世界民眾只能表示呵呵了，姑且把它當作茶餘飯後的談資吧。」德州艾爾帕索郡警方表示，今天凌晨德州艾爾帕索郡（El Paso）以東的郊區沙漠地帶爆發槍擊，一名21歲的男子被擊斃，另有5人受傷。美聯社報導，艾爾帕索郡警長發表聲明說，員警接獲報案趕抵現場，並發現5人身受重傷，但並未具體說明傷勢的細節，也沒有說明死者與傷者的身分。「艾爾帕索時報」（The El Paso Times）報導，歹徒做案動機警方仍在調查中。中國副外長樂玉成昨天接受陸媒專訪時稱，美國衰落的不是實力而是霸權，且思想衰落更危險。他還說，美國的霸權心態和冷戰思維，秀肌肉、舞大棒嚇唬人，「中國人是嚇不倒的」。7月9日是美國前國務卿季辛吉（Henry Kissinger）秘訪中國50週年，樂玉成當天在北京接受陸媒「觀察者網」專訪時，作上述表示。對於美國現任國務卿布林肯（Antony Blinken）說，美國要「從實力地位出發」同中國打交道，樂玉成稱，「這番話骨子裡就是霸權心態和冷戰思維，無非就是秀肌肉、舞大棒嚇唬人」。他又說，「中國人是嚇不倒的，歷史上一窮二白、小米加步槍的時候我們也沒有怕過誰，現在更沒理由怕什麼『實力地位』。」樂玉成並宣稱，美國衰落的不是實力而是霸權。他說，就實力而言，美國仍是全球位居第一的大國、強國。「但實力再強，國霸必衰，霸權不得人心。」他表示，「對一個大國來說，思想的衰落比實力的衰落更危險。在21世紀多極化、全球化時代，不能還想著從冷戰工具箱裡翻找工具，天天琢磨著怎麼遏制他國，拉『小圈子』，搞集團對抗，按叢林法則行事。」樂玉成還說，美國的外交思維是「散發著黴味的陳腐思想」。他甚至批評美國總統拜登（Joe Biden）提出的「重建更好世界」（Build Back Better World，B3W），在中國「一帶一路」建設7年多後才提出，不僅抗衡不了「一帶一路」，反而進一步證明「一帶一路」是正確之路、未來之路。他並反擊美國等西方國家對中國人權的指責。樂玉成宣稱，民主、人權不是標語口號，必須保障人們擁有工作、住房、溫飽、受教育、醫療、養老等基本人權。樂玉成接著宣稱，中共領導14億中國人民擺脫千年貧困，過上幸福生活，就是最大的人權、最好的人權。「可以說中國共產黨在人權問題上不僅無可指責，而且應該給其頒金牌、授勳章。」對於美國要求對中國展開2019冠狀病毒疾病（COVID-19）溯源調查，樂玉成則說，中方已兩次邀請世界衛生組織專家赴中進行溯源研究合作。美方如果真的在乎真相與透明，理應接受國際調查，弄清楚美國疫情的源頭、美國抗疫不力的原因、美國生物實驗基地存在的問題，「而不是拿著手電筒，只照別人，不照自己」。大陸外交部副部長樂玉成接受媒體訪問時，火力全開痛批美國的外交政策與思維。他指出，美國衰落的不是實力而是霸權，而且美國思想的衰落更加危險。樂玉成還指責美國等西方國，本身的人權記錄「劣跡斑斑」，「居然好意思以『人權衛士』、『人權教師爺』自居，對別國頤指氣使、指手畫腳」。7月9日是美國前國務卿季辛吉秘訪中國50周年，樂玉成當天在北京接受網路媒體《觀察者網》專訪。針對美國國務卿布林肯表示，美國要「從實力地位出發」同中國打交道，樂玉成說，這番話骨子裡就是霸權心態和冷戰思維，無非就是秀肌肉、舞大棒嚇唬人。「中國人是嚇不倒的，歷史上一窮二白、小米加步槍的時候我們也沒有怕過誰，現在更沒理由怕什麼『實力地位』。」樂玉成說，美國衰落的不是實力而是霸權，就實力而言，美國仍是全球位居第一的大國、強國。但實力再強，國霸必衰，霸權不得人心。「對一個大國來說，思想的衰落比實力的衰落更危險。在21世紀多極化、全球化時代，不能還想著從冷戰工具箱裡翻找工具，天天琢磨著怎麼遏制他國，拉『小圈子』，搞集團對抗，按叢林法則行事。」樂玉成形容，美國的外交思維是「散發著黴味的陳腐思想」。他甚至批評美國總統拜登提出的「重建更好世界」（Build Back Better World，B3W），在中國「一帶一路」建設7年多後才提出，不僅抗衡不了「一帶一路」，反而進一步證明「一帶一路」是正確之路、未來之路。他指出，「一帶一路」做得好的關鍵是「落到實地」、「幹在實處」，像修路架橋打隧道，都是要真金白銀和流血流汗的，「不是開個會、出個報告、喊個口號就能實現的」。樂玉成還反擊美國等西方國家對中國人權的指責。他強調，民主、人權不是標語口號，它必須保障人們擁有工作、住房、溫飽、受教育、醫療、養老等基本人權。他甚至說，中國共產黨領導14億中國人民擺脫千年貧困，過上幸福生活，就是最大的人權、最好的人權。「可以說中國共產黨在人權問題上不僅無可指責，而且應該給其頒金牌、授勛章。」反觀美國，西進運動大肆殺戮和驅逐印第安人，其人口百餘年間從500萬減至25萬。印地安人曾是北美主體人口，如今只占美國總人口不到2%。樂玉成並指控，時至今日，美國的「弗洛伊德們」還不能呼吸，少數族裔飽受歧視，無家可歸者流浪街頭。而且美國既反華，也反穆斯林，第一個頒「禁穆令」的就是美國。「奇怪的是，美國卻為在新疆地區過著幸福生活的中國穆斯林操『人權』的心，這不是很荒唐可笑嗎？」對於美國要求對中國展開新冠病毒溯源調查，樂玉成稱，中方已兩次邀請世界衛生組織專家來華進行溯源研究合作。美方如果真的在乎真相與透明，理應接受國際調查，弄清楚美國疫情的源頭、美國抗疫不力的原因、美國生物實驗基地存在的問題，「而不是拿著手電筒，只照別人，不照自己」。美國商務部今天增列34家國外實體進入黑名單，包括14個涉嫌在新疆侵犯人權與進行科技監控的中國實體，以及5家支持中國軍事現代化企業，包括列為台灣的杭州華瀾微電子。美國商務部今天發布新聞稿宣布，因為參與或可能參與違反美國外交政策與國家安全利益的活動，工業與安全局（BIS）增列34家企業與實體進入實體 ...

# %%
seg_words_list = jieba.lcut(all_article_text)
seg_words_list
# Out:
# Building prefix dict from /Users/vicar1987/Desktop/Me/從0開始的工程師人生/Text_Mining/Word_Dictionary/dict.txt.big ...
# Loading model from cache /var/folders/6j/gdrt46cd0xz98fn5fj94dl1r0000gp/T/jieba.u4f801de9ebf0d31aaf16dcbc73f2d9c9.cache
# Loading model cost 2.616 seconds.
# Prefix dict has been built successfully.
# ['3',
#  '年來',
#  '2',
#  '位',
#  '美國',
#  '總統',
#  '接連',
#  '努力',
#  '打壓',
#  '中國',
#  '企業',
#  '到',
#  '全球',
#  '最大',
#  '資本',
#  '市場',
#  '美國',
#  '籌資',
#  '，',
#  '如今',
#  '卻',
#  '從',
#  '意想不到',
#  '的',
#  '來源',
#  '獲得',
#  '助力',
#  '：',
#  '中國政府',
#  '。',
#  '日經',
#  '亞洲',
#  '（',
#  'Nikkei',
#  ' ',
#  'Asia',
#  '）',
#  '報導',
#  '，',
#  '北京',
#  '高層',
#  '警告',
#  '對個資',
#  '安全',
#  '和',
#  '企業',
#  '海外',
#  '上市',
#  '將採',
#  '更',
#  '嚴格',
#  '監管',
#  '，',
#  '加上',
#  '中國',
#  '經濟',
#  '成長',
#  '放緩',
#  '及',
#  '政府',
#  '加強',
#  '管理',
#  '，',
#  '已',
#  '使得',
#  '在',
#  '美國',
#  '股票市場',
#  '掛牌',
#  '的',
#  '中國',
#  '企業',
#  '風險',
#  '大增',
#  '，',
#  '因此',
#  '引發',
#  '投資人',
#  '拋售',
#  '潮',
#  '，',
#  '同時',
#  '也',
#  '影響',
#  '到',
#  '其他',
#  '中企',
#  '在',
#  '美國',
#  '上市',
#  '計畫',
#  '。',
#  '根據',
#  '追蹤',
#  '98',
#  '家',
#  '在',
#  '美國',
#  '掛牌',
#  '中企',
#  '股票',
#  '的',
#  '那斯',
#  '達克',
#  '金龍',
#  '中國',
#  '指數',
#  '（',
#  'Nasdaq',
#  ' ',
#  'Golden',
#  ' ',
#  'Dragon',
#  ' ',
#  'China',
#  ' ',
#  'Index',
#  '）',
#  '，',
#  '這類',
#  '中企',
#  '股價',
#  '目前',
#  '和',
#  '美股',
#  '大盤',
#  '差距',
#  '達到',
#  '至少',
#  '是',
#  '2016',
#  '年',
#  '9',
#  '月',
#  '以來',
#  '最高',
#  '，',
#  '比',
#  '美國',
#  '前',
#  '總統',
#  '川普',
#  '（',
#  'Donald',
#  ' ',
#  'Trump',
#  '）',
#  '任內',
#  '美',
#  '中',
#  '貿易戰',
#  '最',
#  '激烈',
#  '時',
#  '的',
#  '低價',
#  '程度',
#  '更',
#  '慘烈',
#  '。',
#  '那斯',
#  '達克',
#  '金龍',
#  '中國',
#  '指數',
#  '從',
#  '本月',
#  '2',
#  '日',
#  '至今',
#  '大跌',
#  '了',
#  '10.5%',
#  '，',
#  '當天',
#  '中國',
#  '國家',
#  '互聯網',
#  '信息',
#  '辦公室',
#  '以',
#  '「',
#  '防範',
#  '國家',
#  '數據安全',
#  '風險',
#  '，',
#  '維護',
#  '國家',
#  '安全',
#  '」',
#  '為',
#  '由',
#  '，',
#  '對',
#  '2',
#  '天前',
#  '才',
#  '在',
#  '美國',
#  '首次',
#  '公開',
#  '募股',
#  '（',
#  'IPO',
#  '）',
#  '、',
#  '籌得',
#  '44',
#  '億美元',
#  '（',
#  '約',
#  '新',
#  '台幣',
#  '1232',
#  '億元',
#  '）',
#  '的',
#  '中國',
#  '最大',
#  '叫車',
#  '服務',
#  '軟體',
#  '公司',
#  '滴滴',
#  '出行',
#  '實施',
#  '網路',
#  '安全',
#  '審查',
#  '，',
#  '期間',
#  '停止',
#  '新',
#  '用戶註冊',
#  '。',
#  '那斯',
#  '達克',
#  '金龍',
#  '中國',
#  '指數',
#  '和',
#  '大盤',
#  '指數',
#  '的',
#  '差距',
#  '，',
#  '也',
#  '以',
#  '至少',
#  '5',
#  '年來',
#  '最快',
#  '速度',
#  '擴大',
#  '，',
#  '反映',
#  '出',
#  '投資人',
#  '情緒',
#  '迅速',
#  '轉變',
#  '及',
#  '市場',
#  '受驚嚇',
#  '的',
#  '程度',
#  '。',
#  '中國',
#  '網信',
#  '辦',
#  '10',
#  '日',
#  '更進一步',
#  '公告',
#  '「',
#  '網絡安全',
#  '審查',
#  '辦法',
#  '」',
#  '修訂',
#  '草案',
#  '，',
#  '規定',
#  '掌握',
#  '超過',
#  '100',
#  '萬',
#  '用戶',
#  '個資',
#  '的',
#  '企業',
#  '若',
#  '欲',
#  '赴',
#  '海外',
#  '上市',
#  '，',
#  '須',
#  '申請',
#  '網路',
#  '安全',
#  '審查',
#  '。',
#  '這',
#  '幾乎',
#  '影響',
#  '到',
#  '所有',
#  '有意',
#  '在',
#  '海外',
#  'IPO',
#  '的',
#  '中企',
#  '。',
#  '分析師',
#  '發現',
#  '，',
#  '北京',
#  '的',
#  '動機',
#  '是',
#  '要',
#  '減少',
#  '中國',
#  '對',
#  '美國',
#  '和',
#  '美方',
#  '監管',
#  '當局',
#  '的',
#  '曝險',
#  '；',
#  '一方面',
#  '是',
#  '為',
#  '保護',
#  '資訊',
#  '，',
#  '另',
#  '方面',
#  '降低',
#  '中國',
#  '企業',
#  '對',
#  '全球',
#  '最大',
#  '資本',
#  '市場',
#  '美國',
#  '的',
#  '籌資',
#  '依賴',
#  '。',
#  '川普',
#  '2018',
#  '年',
#  '開打',
#  '貿易戰',
#  '，',
#  '迫使',
#  '中國',
#  '去年',
#  '宣布',
#  '在',
#  '科技',
#  '和',
#  '半導體',
#  '等',
#  '重要',
#  '產業',
#  '推動',
#  '自給自足',
#  '的',
#  '計畫',
#  '。',
#  '川普',
#  '在',
#  '任期',
#  '尾聲',
#  '還對',
#  '連串',
#  '中國',
#  '企業',
#  '祭',
#  '出',
#  '投資',
#  '禁令',
#  '，',
#  '並',
#  '贊成',
#  '實施',
#  '規定',
#  '令',
#  '中企',
#  '下',
#  '市',
#  '。',
#  '美國',
#  '去年',
#  '已',
#  '通過',
#  '立法',
#  '，',
#  '要求',
#  '在',
#  '美國',
#  '掛牌',
#  '的',
#  '中國',
#  '企業',
#  '必須',
#  '讓',
#  '美國',
#  '監管',
#  '機關',
#  '審查',
#  '會計',
#  '審計',
#  '紀錄',
#  '，',
#  '否則',
#  '可能',
#  '將在',
#  '2023',
#  '年底',
#  '前',
#  '被迫',
#  '下',
#  '市',
#  '。',
#  '現任',
#  '美國',
#  '總統',
#  '拜登',
#  '（',
#  'Joe',
#  ' ',
#  'Biden',
#  '）',
#  '至今',
#  '也',
#  '大致',
#  '維持',
#  '川普',
#  '政府',
#  '對',
#  '北京',
#  '的',
#  '施壓',
#  '，',
#  '他',
#  '6',
#  '月',
#  '簽署',
#  '行政命令',
#  '，',
#  '禁止',
#  '美國',
#  '居民',
#  '和',
#  '實體',
#  '投資',
#  '據控',
#  '與',
#  '解放軍',
#  '有',
#  '關係',
#  '的',
#  '59',
#  '家',
#  '中國',
#  '企業',
#  '。',
#  '包括',
#  '中國移動',
#  '等',
#  '數家',
#  '中國電信',
#  '企業',
#  '已',
#  '在',
#  '美國',
#  '交易所',
#  '下',
#  '市',
#  '。',
#  '但',
#  '根據',
#  '美國國會',
#  '授權',
#  '成立',
#  '的',
#  '「',
#  '美',
#  '中',
#  '經濟',
#  '暨',
#  '安全',
#  '檢討',
#  '委員會',
#  '」',
#  '（',
#  'US',
#  '-',
#  'China',
#  ' ',
#  'Economic',
#  ' ',
#  'and',
#  ' ',
#  'Security',
#  ' ',
#  'ReviewCommission',
#  '）',
#  '統計',
#  '，',
#  '截至',
#  '今年',
#  '5',
#  '月',
#  '5',
#  '日',
#  '，',
#  '共有',
#  '248',
#  '家中',
#  '企在',
#  '美國',
#  '股票',
#  '交易所',
#  '上市',
#  '，',
#  '合計',
#  '市值',
#  '達到',
#  '2',
#  '兆',
#  '1000',
#  '億美元',
#  '（',
#  '近新',
#  '台幣',
#  '59',
#  '兆元',
#  '）',
#  '。',
#  '「',
#  '紅色',
#  '資本主義',
#  '：',
#  '中國',
#  '驚人',
#  '崛起',
#  '的',
#  '脆弱',
#  '金融',
#  '基礎',
#  '」',
#  '（',
#  'Red',
#  ' ',
#  'Capitalism',
#  ':',
#  ' ',
#  'The',
#  ' ',
#  'Fragile',
#  ' ',
#  'FinancialFoundation',
#  ' ',
#  'of',
#  ' ',
#  'China',
#  "'",
#  's',
#  ' ',
#  'Extraordinary',
#  ' ',
#  'Rise',
#  '，',
#  '暫譯',
#  '）',
#  '一書',
#  '共同',
#  '作者',
#  '、',
#  '市場',
#  '分析師',
#  '郝伊',
#  '（',
#  'Fraser',
#  ' ',
#  'Howie',
#  '）',
#  '表示',
#  '：',
#  '「',
#  '長期以來',
#  '，',
#  '中國',
#  '渴望',
#  '在',
#  '眾多',
#  '產業',
#  '達到',
#  '自給自足',
#  '，',
#  '其中',
#  '若',
#  '包含',
#  '資本',
#  '市場',
#  '也',
#  '很',
#  '合理',
#  '。',
#  '」',
#  '郝伊說',
#  '：',
#  '「',
#  '中國',
#  '會',
#  '比較',
#  '希望',
#  '國內',
#  '企業',
#  '在',
#  '境內',
#  '掛牌',
#  '，',
#  '或',
#  '至少',
#  '在',
#  '香港',
#  '上市',
#  '，',
#  '因為',
#  '北京',
#  '想要',
#  '由',
#  '他們',
#  '來',
#  '監管',
#  '自家',
#  '企業',
#  '。',
#  '至於',
#  '已',
#  '赴',
#  '海外',
#  '上市',
#  '中企',
#  '，',
#  '他們',
#  '的',
#  '成長',
#  '展望',
#  '已',
#  '不再',
#  '亮眼',
#  '，',
#  '投資人',
#  '已',
#  '開始',
#  '對',
#  '這類',
#  '股票',
#  '重新估價',
#  '。',
#  '」',
#  '大陸',
#  '外交部',
#  '發言人',
#  '趙',
#  '立堅',
#  '今天',
#  '主持',
#  '例行',
#  '記者會',
#  '，',
#  '有',
#  '記者',
#  '提問',
#  '，',
#  '彭博社',
#  '日前',
#  '發布',
#  '新一期',
#  '的',
#  '全球',
#  '抗疫',
#  '排名',
#  '，',
#  '美國',
#  '排名',
#  '第一',
#  '，',
#  '成為',
#  '全球',
#  '第一',
#  '抗疫',
#  '大國',
#  '，',
#  '中國',
#  '排名',
#  '第八',
#  '，',
#  '中',
#  '方有何',
#  '評論',
#  '？',
#  '趙',
#  '立堅',
#  '回應',
#  '說',
#  '：',
#  '「',
#  '這',
#  '幾天',
#  '我',
#  '的',
#  '好幾位',
#  '同事',
#  '和',
#  '朋友',
#  '都',
#  '在',
#  '問我',
#  '，',
#  '彭博社',
#  '這個',
#  '報告',
#  '是不是',
#  '印錯',
#  '了',
#  '？',
#  '他們',
#  '還問',
#  '，',
#  '在',
#  '他們',
#  '心中',
#  '一向',
#  '權威',
#  '的',
#  '彭博社',
#  '，',
#  '怎麼',
#  '能',
#  '如此',
#  '小兒科',
#  '？',
#  '」',
#  '他並',
#  '指出',
#  '，',
#  '看到',
#  '有關',
#  '報導',
#  '說',
#  '，',
#  '彭博社',
#  '的',
#  '所謂',
#  '全球',
#  '抗疫',
#  '排名',
#  '，',
#  '為',
#  '了',
#  '達到',
#  '美國',
#  '第一',
#  '的',
#  '結果',
#  '，',
#  '不惜',
#  '將',
#  '以往',
#  '排名',
#  '中',
#  '最',
#  '為',
#  '關鍵',
#  '的',
#  '確診',
#  '病例',
#  '和',
#  '死亡',
#  '人數',
#  '等',
#  '要素',
#  '刪掉',
#  '，',
#  '並將',
#  '執行',
#  '封鎖',
#  '和',
#  '出入境',
#  '防疫',
#  '管理',
#  '政策',
#  '視為',
#  '負面',
#  '因素',
#  '，',
#  '這既不',
#  '符合事實',
#  '，',
#  '也',
#  '不',
#  '尊重',
#  '科學',
#  '，',
#  '更',
#  '不',
#  '尊重',
#  '生命',
#  '。',
#  '趙',
#  '立堅',
#  '說',
#  '，',
#  '中國',
#  '人常',
#  '說',
#  '，',
#  '老百姓',
#  '心中',
#  '有',
#  '桿秤',
#  '，',
#  '群眾',
#  '的',
#  '眼睛',
#  '是',
#  '雪亮',
#  '的',
#  '。',
#  '所謂',
#  '的',
#  '排名',
#  '和',
#  '民調',
#  '結果',
#  '，',
#  '把',
#  '黑',
#  '的',
#  '說',
#  '成白',
#  '的',
#  '，',
#  '白',
#  '的',
#  '說',
#  '成',
#  '黑',
#  '的',
#  '，',
#  '也許',
#  '今後',
#  '還能',
#  '把',
#  '死',
#  '的',
#  '說',
#  '成活',
#  '的',
#  '。',
#  '「',
#  '我',
#  '想',
#  '世界',
#  '民眾',
#  '只能',
#  '表示',
#  '呵呵',
#  '了',
#  '，',
#  '姑且',
#  '把',
#  '它',
#  '當作',
#  '茶餘飯後',
#  '的',
#  '談資',
#  '吧',
#  '。',
#  '」',
#  '德州',
#  '艾爾帕索',
#  '郡',
#  '警方',
#  '表示',
#  '，',
#  '今天',
#  '凌晨',
#  '德州',
#  '艾爾帕索',
#  '郡',
#  '（',
#  'El',
#  ' ',
#  'Paso',
#  '）',
#  '以東',
#  '的',
#  '郊區',
#  '沙漠',
#  '地帶',
#  '爆發',
#  '槍擊',
#  '，',
#  '一名',
#  '21',
#  '歲',
#  '的',
#  '男子',
#  '被',
#  '擊斃',
#  '，',
#  '另有',
#  '5',
#  '人',
#  '受傷',
#  '。',
#  '美聯社',
#  '報導',
#  '，',
#  '艾爾帕索',
#  '郡',
#  '警長',
#  '發表',
#  '聲',
#  '明說',
#  '，',
#  '員警',
#  '接獲',
#  '報案',
#  '趕抵',
#  '現場',
#  '，',
#  '並',
#  '發現',
#  '5',
#  '人',
#  '身受',
#  '重傷',
#  '，',
#  '但',
#  '並未',
#  '具體',
#  '說明',
#  '傷勢',
#  '的',
#  '細節',
#  '，',
#  '也',
#  '沒有',
#  '說明',
#  '死者',
#  '與',
#  '傷者',
#  '的',
#  '身分',
#  '。',
#  '「',
#  '艾爾帕索',
#  '時報',
#  '」',
#  '（',
#  'The',
#  ' ',
#  'El',
#  ' ',
#  'Paso',
#  ' ',
#  'Times',
#  '）',
#  '報導',
#  '，',
#  '歹徒',
#  '做案',
#  '動機',
#  '警方',
#  '仍',
#  '在',
#  '調查',
#  '中',
#  '。',
#  '中國',
#  '副外長',
#  '樂',
#  '玉成',
#  '昨天',
#  '接受',
#  ...]

# %%
with open(file='Word_Dictionary/stop_words.txt', mode='r', encoding='utf-8') as file:
    stop_words = file.read().split('\n')
stop_words
# Out:
# ['the',
#  'of',
#  'is',
#  'and',
#  'to',
#  'in',
#  'that',
#  'we',
#  'for',
#  'an',
#  'are',
#  'by',
#  'be',
#  'as',
#  'on',
#  'with',
#  'can',
#  'if',
#  'from',
#  'which',
#  'you',
#  'it',
#  'this',
#  'then',
#  'at',
#  'have',
#  'all',
#  'not',
#  'one',
#  'has',
#  'or',
#  'that',
#  '的',
#  '了',
#  '和',
#  '是',
#  '就',
#  '都',
#  '而',
#  '及',
#  '與',
#  '著',
#  '或',
#  '一個',
#  '沒有',
#  '我們',
#  '你們',
#  '妳們',
#  '他們',
#  '她們',
#  '是否',
#  '，',
#  '「',
#  '」',
#  '。',
#  '：',
#  '！',
#  '？',
#  '／',
#  '＼',
#  '（',
#  '）',
#  '、',
#  '\u3000',
#  '『',
#  '』',
#  '-',
#  '《',
#  '》',
#  ' ']

# %%
seg_stop_words_list = []
seg_words_list = jieba.lcut(all_article_text)
for term in seg_words_list:
    if term not in stop_words:
        seg_stop_words_list.append(term)
seg_stop_words_list
# Out:
# ['3',
#  '年來',
#  '2',
#  '位',
#  '美國',
#  '總統',
#  '接連',
#  '努力',
#  '打壓',
#  '中國',
#  '企業',
#  '到',
#  '全球',
#  '最大',
#  '資本',
#  '市場',
#  '美國',
#  '籌資',
#  '如今',
#  '卻',
#  '從',
#  '意想不到',
#  '來源',
#  '獲得',
#  '助力',
#  '中國政府',
#  '日經',
#  '亞洲',
#  'Nikkei',
#  'Asia',
#  '報導',
#  '北京',
#  '高層',
#  '警告',
#  '對個資',
#  '安全',
#  '企業',
#  '海外',
#  '上市',
#  '將採',
#  '更',
#  '嚴格',
#  '監管',
#  '加上',
#  '中國',
#  '經濟',
#  '成長',
#  '放緩',
#  '政府',
#  '加強',
#  '管理',
#  '已',
#  '使得',
#  '在',
#  '美國',
#  '股票市場',
#  '掛牌',
#  '中國',
#  '企業',
#  '風險',
#  '大增',
#  '因此',
#  '引發',
#  '投資人',
#  '拋售',
#  '潮',
#  '同時',
#  '也',
#  '影響',
#  '到',
#  '其他',
#  '中企',
#  '在',
#  '美國',
#  '上市',
#  '計畫',
#  '根據',
#  '追蹤',
#  '98',
#  '家',
#  '在',
#  '美國',
#  '掛牌',
#  '中企',
#  '股票',
#  '那斯',
#  '達克',
#  '金龍',
#  '中國',
#  '指數',
#  'Nasdaq',
#  'Golden',
#  'Dragon',
#  'China',
#  'Index',
#  '這類',
#  '中企',
#  '股價',
#  '目前',
#  '美股',
#  '大盤',
#  '差距',
#  '達到',
#  '至少',
#  '2016',
#  '年',
#  '9',
#  '月',
#  '以來',
#  '最高',
#  '比',
#  '美國',
#  '前',
#  '總統',
#  '川普',
#  'Donald',
#  'Trump',
#  '任內',
#  '美',
#  '中',
#  '貿易戰',
#  '最',
#  '激烈',
#  '時',
#  '低價',
#  '程度',
#  '更',
#  '慘烈',
#  '那斯',
#  '達克',
#  '金龍',
#  '中國',
#  '指數',
#  '從',
#  '本月',
#  '2',
#  '日',
#  '至今',
#  '大跌',
#  '10.5%',
#  '當天',
#  '中國',
#  '國家',
#  '互聯網',
#  '信息',
#  '辦公室',
#  '以',
#  '防範',
#  '國家',
#  '數據安全',
#  '風險',
#  '維護',
#  '國家',
#  '安全',
#  '為',
#  '由',
#  '對',
#  '2',
#  '天前',
#  '才',
#  '在',
#  '美國',
#  '首次',
#  '公開',
#  '募股',
#  'IPO',
#  '籌得',
#  '44',
#  '億美元',
#  '約',
#  '新',
#  '台幣',
#  '1232',
#  '億元',
#  '中國',
#  '最大',
#  '叫車',
#  '服務',
#  '軟體',
#  '公司',
#  '滴滴',
#  '出行',
#  '實施',
#  '網路',
#  '安全',
#  '審查',
#  '期間',
#  '停止',
#  '新',
#  '用戶註冊',
#  '那斯',
#  '達克',
#  '金龍',
#  '中國',
#  '指數',
#  '大盤',
#  '指數',
#  '差距',
#  '也',
#  '以',
#  '至少',
#  '5',
#  '年來',
#  '最快',
#  '速度',
#  '擴大',
#  '反映',
#  '出',
#  '投資人',
#  '情緒',
#  '迅速',
#  '轉變',
#  '市場',
#  '受驚嚇',
#  '程度',
#  '中國',
#  '網信',
#  '辦',
#  '10',
#  '日',
#  '更進一步',
#  '公告',
#  '網絡安全',
#  '審查',
#  '辦法',
#  '修訂',
#  '草案',
#  '規定',
#  '掌握',
#  '超過',
#  '100',
#  '萬',
#  '用戶',
#  '個資',
#  '企業',
#  '若',
#  '欲',
#  '赴',
#  '海外',
#  '上市',
#  '須',
#  '申請',
#  '網路',
#  '安全',
#  '審查',
#  '這',
#  '幾乎',
#  '影響',
#  '到',
#  '所有',
#  '有意',
#  '在',
#  '海外',
#  'IPO',
#  '中企',
#  '分析師',
#  '發現',
#  '北京',
#  '動機',
#  '要',
#  '減少',
#  '中國',
#  '對',
#  '美國',
#  '美方',
#  '監管',
#  '當局',
#  '曝險',
#  '；',
#  '一方面',
#  '為',
#  '保護',
#  '資訊',
#  '另',
#  '方面',
#  '降低',
#  '中國',
#  '企業',
#  '對',
#  '全球',
#  '最大',
#  '資本',
#  '市場',
#  '美國',
#  '籌資',
#  '依賴',
#  '川普',
#  '2018',
#  '年',
#  '開打',
#  '貿易戰',
#  '迫使',
#  '中國',
#  '去年',
#  '宣布',
#  '在',
#  '科技',
#  '半導體',
#  '等',
#  '重要',
#  '產業',
#  '推動',
#  '自給自足',
#  '計畫',
#  '川普',
#  '在',
#  '任期',
#  '尾聲',
#  '還對',
#  '連串',
#  '中國',
#  '企業',
#  '祭',
#  '出',
#  '投資',
#  '禁令',
#  '並',
#  '贊成',
#  '實施',
#  '規定',
#  '令',
#  '中企',
#  '下',
#  '市',
#  '美國',
#  '去年',
#  '已',
#  '通過',
#  '立法',
#  '要求',
#  '在',
#  '美國',
#  '掛牌',
#  '中國',
#  '企業',
#  '必須',
#  '讓',
#  '美國',
#  '監管',
#  '機關',
#  '審查',
#  '會計',
#  '審計',
#  '紀錄',
#  '否則',
#  '可能',
#  '將在',
#  '2023',
#  '年底',
#  '前',
#  '被迫',
#  '下',
#  '市',
#  '現任',
#  '美國',
#  '總統',
#  '拜登',
#  'Joe',
#  'Biden',
#  '至今',
#  '也',
#  '大致',
#  '維持',
#  '川普',
#  '政府',
#  '對',
#  '北京',
#  '施壓',
#  '他',
#  '6',
#  '月',
#  '簽署',
#  '行政命令',
#  '禁止',
#  '美國',
#  '居民',
#  '實體',
#  '投資',
#  '據控',
#  '解放軍',
#  '有',
#  '關係',
#  '59',
#  '家',
#  '中國',
#  '企業',
#  '包括',
#  '中國移動',
#  '等',
#  '數家',
#  '中國電信',
#  '企業',
#  '已',
#  '在',
#  '美國',
#  '交易所',
#  '下',
#  '市',
#  '但',
#  '根據',
#  '美國國會',
#  '授權',
#  '成立',
#  '美',
#  '中',
#  '經濟',
#  '暨',
#  '安全',
#  '檢討',
#  '委員會',
#  'US',
#  'China',
#  'Economic',
#  'Security',
#  'ReviewCommission',
#  '統計',
#  '截至',
#  '今年',
#  '5',
#  '月',
#  '5',
#  '日',
#  '共有',
#  '248',
#  '家中',
#  '企在',
#  '美國',
#  '股票',
#  '交易所',
#  '上市',
#  '合計',
#  '市值',
#  '達到',
#  '2',
#  '兆',
#  '1000',
#  '億美元',
#  '近新',
#  '台幣',
#  '59',
#  '兆元',
#  '紅色',
#  '資本主義',
#  '中國',
#  '驚人',
#  '崛起',
#  '脆弱',
#  '金融',
#  '基礎',
#  'Red',
#  'Capitalism',
#  ':',
#  'The',
#  'Fragile',
#  'FinancialFoundation',
#  'China',
#  "'",
#  's',
#  'Extraordinary',
#  'Rise',
#  '暫譯',
#  '一書',
#  '共同',
#  '作者',
#  '市場',
#  '分析師',
#  '郝伊',
#  'Fraser',
#  'Howie',
#  '表示',
#  '長期以來',
#  '中國',
#  '渴望',
#  '在',
#  '眾多',
#  '產業',
#  '達到',
#  '自給自足',
#  '其中',
#  '若',
#  '包含',
#  '資本',
#  '市場',
#  '也',
#  '很',
#  '合理',
#  '郝伊說',
#  '中國',
#  '會',
#  '比較',
#  '希望',
#  '國內',
#  '企業',
#  '在',
#  '境內',
#  '掛牌',
#  '至少',
#  '在',
#  '香港',
#  '上市',
#  '因為',
#  '北京',
#  '想要',
#  '由',
#  '來',
#  '監管',
#  '自家',
#  '企業',
#  '至於',
#  '已',
#  '赴',
#  '海外',
#  '上市',
#  '中企',
#  '成長',
#  '展望',
#  '已',
#  '不再',
#  '亮眼',
#  '投資人',
#  '已',
#  '開始',
#  '對',
#  '這類',
#  '股票',
#  '重新估價',
#  '大陸',
#  '外交部',
#  '發言人',
#  '趙',
#  '立堅',
#  '今天',
#  '主持',
#  '例行',
#  '記者會',
#  '有',
#  '記者',
#  '提問',
#  '彭博社',
#  '日前',
#  '發布',
#  '新一期',
#  '全球',
#  '抗疫',
#  '排名',
#  '美國',
#  '排名',
#  '第一',
#  '成為',
#  '全球',
#  '第一',
#  '抗疫',
#  '大國',
#  '中國',
#  '排名',
#  '第八',
#  '中',
#  '方有何',
#  '評論',
#  '趙',
#  '立堅',
#  '回應',
#  '說',
#  '這',
#  '幾天',
#  '我',
#  '好幾位',
#  '同事',
#  '朋友',
#  '在',
#  '問我',
#  '彭博社',
#  '這個',
#  '報告',
#  '是不是',
#  '印錯',
#  '還問',
#  '在',
#  '心中',
#  '一向',
#  '權威',
#  '彭博社',
#  '怎麼',
#  '能',
#  '如此',
#  '小兒科',
#  '他並',
#  '指出',
#  '看到',
#  '有關',
#  '報導',
#  '說',
#  '彭博社',
#  '所謂',
#  '全球',
#  '抗疫',
#  '排名',
#  '為',
#  '達到',
#  '美國',
#  '第一',
#  '結果',
#  '不惜',
#  '將',
#  '以往',
#  '排名',
#  '中',
#  '最',
#  '為',
#  '關鍵',
#  '確診',
#  '病例',
#  '死亡',
#  '人數',
#  '等',
#  '要素',
#  '刪掉',
#  '並將',
#  '執行',
#  '封鎖',
#  '出入境',
#  '防疫',
#  '管理',
#  '政策',
#  '視為',
#  '負面',
#  '因素',
#  '這既不',
#  '符合事實',
#  '也',
#  '不',
#  '尊重',
#  '科學',
#  '更',
#  '不',
#  '尊重',
#  '生命',
#  '趙',
#  '立堅',
#  '說',
#  '中國',
#  '人常',
#  '說',
#  '老百姓',
#  '心中',
#  '有',
#  '桿秤',
#  '群眾',
#  '眼睛',
#  '雪亮',
#  '所謂',
#  '排名',
#  '民調',
#  '結果',
#  '把',
#  '黑',
#  '說',
#  '成白',
#  '白',
#  '說',
#  '成',
#  '黑',
#  '也許',
#  '今後',
#  '還能',
#  '把',
#  '死',
#  '說',
#  '成活',
#  '我',
#  '想',
#  '世界',
#  '民眾',
#  '只能',
#  '表示',
#  '呵呵',
#  '姑且',
#  '把',
#  '它',
#  '當作',
#  '茶餘飯後',
#  '談資',
#  '吧',
#  '德州',
#  '艾爾帕索',
#  '郡',
#  '警方',
#  '表示',
#  '今天',
#  '凌晨',
#  '德州',
#  '艾爾帕索',
#  '郡',
#  'El',
#  'Paso',
#  '以東',
#  '郊區',
#  '沙漠',
#  '地帶',
#  '爆發',
#  '槍擊',
#  '一名',
#  '21',
#  '歲',
#  '男子',
#  '被',
#  '擊斃',
#  '另有',
#  '5',
#  '人',
#  '受傷',
#  '美聯社',
#  '報導',
#  '艾爾帕索',
#  '郡',
#  '警長',
#  '發表',
#  '聲',
#  '明說',
#  '員警',
#  '接獲',
#  '報案',
#  '趕抵',
#  '現場',
#  '並',
#  '發現',
#  '5',
#  '人',
#  '身受',
#  '重傷',
#  '但',
#  '並未',
#  '具體',
#  '說明',
#  '傷勢',
#  '細節',
#  '也',
#  '說明',
#  '死者',
#  '傷者',
#  '身分',
#  '艾爾帕索',
#  '時報',
#  'The',
#  'El',
#  'Paso',
#  'Times',
#  '報導',
#  '歹徒',
#  '做案',
#  '動機',
#  '警方',
#  '仍',
#  '在',
#  '調查',
#  '中',
#  '中國',
#  '副外長',
#  '樂',
#  '玉成',
#  '昨天',
#  '接受',
#  '陸媒',
#  '專訪',
#  '時稱',
#  '美國',
#  '衰落',
#  '不是',
#  '實力',
#  '而是',
#  '霸權',
#  '且',
#  '思想',
#  '衰落',
#  '更',
#  '危險',
#  '他',
#  '還說',
#  '美國',
#  '霸權',
#  '心態',
#  '冷戰',
#  '思維',
#  '秀',
#  '肌肉',
#  '舞',
#  '大棒',
#  '嚇唬人',
#  '中國',
#  '人',
#  '嚇不倒',
#  '7',
#  '月',
#  '9',
#  '日',
#  '美國',
#  '前',
#  '國務卿',
#  '季辛吉',
#  'Henry',
#  'Kissinger',
#  '秘訪',
#  '中國',
#  '50',
#  '週年',
#  '樂',
#  '玉成',
#  '當天',
#  '在',
#  '北京',
#  '接受',
#  '陸媒',
#  '觀察者',
#  '網',
#  '專訪',
#  '時',
#  '作',
#  '上述',
#  '表示',
#  '對於',
#  '美國',
#  '現任',
#  '國務卿',
#  '布',
#  '林肯',
#  'Antony',
#  'Blinken',
#  '說',
#  '美國',
#  '要',
#  '從實',
#  '力',
#  '地位',
#  '出發',
#  '同',
#  '中國',
#  '打交道',
#  '樂',
#  '玉成',
#  '稱',
#  '這番話',
#  '骨子',
#  '裡',
#  '就是',
#  '霸權',
#  '心態',
#  '冷戰',
#  '思維',
#  '無非',
#  '就是',
#  '秀',
#  '肌肉',
#  '舞',
#  '大棒',
#  '嚇唬人',
#  '他',
#  '又',
#  '說',
#  '中國',
#  '人',
#  '嚇不倒',
#  '歷史',
#  '上',
#  '一窮二白',
#  '小米',
#  '加',
#  '步槍',
#  '時候',
#  '也',
#  '怕過',
#  '誰',
#  '現在',
#  '更',
#  '沒理由',
#  '怕',
#  '什麼',
#  '實力',
#  '地位',
#  '樂',
#  '玉成',
#  '並',
#  '宣稱',
#  '美國',
#  '衰落',
#  '不是',
#  '實力',
#  '而是',
#  '霸權',
#  '他',
#  '說',
#  '實力',
#  '而言',
#  '美國',
#  '仍',
#  '全球',
#  '位居',
#  '第一',
#  '大國',
#  '強國',
#  '但',
#  '實力',
#  '再強',
#  '國霸',
#  '必衰',
#  '霸權',
#  '不得人心',
#  '他',
#  '表示',
#  '對',
#  '大國',
#  '來說',
#  '思想',
#  '衰落',
#  '比',
#  '實力',
#  '衰落',
#  '更',
#  '危險',
#  '在',
#  '21',
#  '世紀',
#  '多極化',
#  '全球化',
#  '時代',
#  '不能',
#  '還想',
#  '從',
#  '冷戰',
#  '工具箱',
#  '裡',
#  '翻找',
#  '工具',
#  '天天',
#  '琢磨',
#  '怎麼',
#  '遏制',
#  '他',
#  '國',
#  '拉',
#  '小圈子',
#  '搞',
#  '集團',
#  '對抗',
#  '按',
#  '叢林',
#  '法則',
#  '行事',
#  '樂',
#  '玉成',
#  '還說',
#  '美國',
#  '外交',
#  '思維',
#  '散發',
#  '黴味',
#  '陳腐',
#  '思想',
#  '他',
#  '甚至',
#  '批評',
#  '美國',
#  '總統',
#  '拜登',
#  'Joe',
#  'Biden',
#  '提出',
#  '重建',
#  '更好',
#  '世界',
#  'Build',
#  'Back',
#  'Better',
#  'World',
#  'B3W',
#  '在',
#  '中國',
#  '一帶',
#  '一路',
#  '建設',
#  '7',
#  '年',
#  '多後才',
#  '提出',
#  '不僅',
#  '抗衡',
#  '不了',
#  '一帶',
#  '一路',
#  '反而',
#  '進一步',
#  '證明',
#  '一帶',
#  '一路',
#  '正確',
#  '之',
#  '路',
#  '未來',
#  '之',
#  '路',
#  '他並',
#  ...]

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
# Requirement already satisfied: numpy>=1.6.1 in /Users/vicar1987/.conda/envs/pythonProject/lib/python3.9/site-packages (from wordcloud) (1.21.0)
# Collecting pillow
#   Using cached Pillow-8.3.1-cp39-cp39-macosx_10_10_x86_64.whl (2.9 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.4.2-cp39-cp39-macosx_10_9_x86_64.whl (7.2 MB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/vicar1987/.conda/envs/pythonProject/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.1)
# Collecting pyparsing>=2.2.1
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.1-cp39-cp39-macosx_10_9_x86_64.whl (61 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: six in /Users/vicar1987/.conda/envs/pythonProject/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py) ... done
#   Created wheel for wordcloud: filename=wordcloud-1.8.1-cp39-cp39-macosx_10_9_x86_64.whl size=154242 sha256=0e436e110c1251a8c07f42758746fd613c51a4c527bd09e1b7c5a0faae71dc41
#   Stored in directory: /Users/vicar1987/Library/Caches/pip/wheels/f9/7a/dd/06ef8b5dfe5483f6204133c08eeb16c287cc2c05e290ae2fc0
# Successfully built wordcloud
# Installing collected packages: pyparsing, pillow, kiwisolver, cycler, matplotlib, wordcloud
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pillow-8.3.1 pyparsing-2.4.7 wordcloud-1.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
print(matplotlib.matplotlib_fname())
# Out:
# /Users/vicar1987/.conda/envs/pythonProject/lib/python3.9/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
seg_words = ' '.join(seg_words_list)

# %%
wordcloud = WordCloud(font_path='/Library/Fonts/Microsof/Microsoft Jhenghei.ttf').generate(seg_words)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from collections import Counter
seg_stop_counter = Counter(seg_stop_words_list)

# %%
wordcloud = WordCloud(font_path='/Library/Fonts/Microsof/Microsoft Jhenghei.ttf').generate_from_frequencies(seg_stop_counter)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
